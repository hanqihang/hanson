# %%
print("hello world!")
# Out:
# hello world!

# %%
x = 6
y = "helloworld"
print(y[2])
print(y[2:4])
print(y[::-1])
y.find("e") #if finded, print the index; if not, print -1

for i in range(10):
    x += 1
# Out:
# l
# ll
# dlrowolleh

# %%
print(x)
# Out:
# 16
